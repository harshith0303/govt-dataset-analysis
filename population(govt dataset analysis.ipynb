# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats


df = pd.read_csv("Projected_Population_for_2022.csv")

df
# Out:
#                   Taluk  Projected_Population_2023_Male  \
# 0              Chikkodi                          240783
# 1                Athani                          225855
# 2                Raibag                          249200
# 3                 Gokak                          241911
# 4               Hukkeri                          229155
# ..                  ...                             ...
# 231  Hagaribommanahalli                          109561
# 232       Harapanahalli                          177083
# 233             Kotturu                           56276
# 234            Hadagali                          117916
# 235         State_total                        37516062
#
#      Projected_Population_2023_Female  Projected_Population_2023_Total  \
# 0                              231377                           472160
# 1                              216307                           442162
# 2                              238619                           487819
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 6 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Taluk                                 236 non-null    object
#  1   Projected_Population_2023_Male        236 non-null    int64
#  2   Projected_Population_2023_Female      236 non-null    int64
#  3   Projected_Population_2023_Total       236 non-null    int64
#  4   Percentage Share to Total Population  236 non-null    float64
#  5   Rank                                  235 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 11.2+ KB

# %%
df.fillna({'Rank': df['Rank'].median()}, inplace=True)  # Filling missing rank with median

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.describe())
# Out:
#        Projected_Population_2023_Male  Projected_Population_2023_Female  \
# count                    2.360000e+02                      2.360000e+02
# mean                     3.179327e+05                      3.093372e+05
# std                      2.447959e+06                      2.380867e+06
# min                      1.515900e+04                      1.476700e+04
# 25%                      7.433600e+04                      7.248675e+04
# 50%                      1.095495e+05                      1.071580e+05
# 75%                      1.631665e+05                      1.607122e+05
# max                      3.751606e+07                      3.650179e+07
#
#        Projected_Population_2023_Total  Percentage Share to Total Population  \
# count                     2.360000e+02                            236.000000
# mean                      6.272699e+05                             13.559534
# std                       4.828814e+06                             10.216367
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236 entries, 0 to 235
# Data columns (total 6 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Taluk                                 236 non-null    object
#  1   Projected_Population_2023_Male        236 non-null    int64
#  2   Projected_Population_2023_Female      236 non-null    int64
#  3   Projected_Population_2023_Total       236 non-null    int64
#  4   Percentage Share to Total Population  236 non-null    float64
#  5   Rank                                  236 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 12.9+ KB

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['Projected_Population_2023_Total'], bins=30, kde=True)
plt.title("Distribution of Projected Total Population")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['Projected_Population_2023_Male'], bins=30, kde=True)
plt.title("Distribution of Projected Total Population")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['Projected_Population_2023_Female'], bins=30, kde=True)
plt.title("Distribution of Projected Total Population")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Projected_Population_2023_Female'], color="lightblue")
plt.title("Boxplot of Population")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Projected_Population_2023_Male'], color="lightblue")
plt.title("Boxplot of Population")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Projected_Population_2023_Total'], color="lightblue")
plt.title("Boxplot of Population")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=df['Taluk'], y=df['Projected_Population_2023_Total'], palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("Region")
plt.ylabel("Total Population")
plt.title("Population by Region")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=df['Taluk'], y=df['Projected_Population_2023_Male'], palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("Region")
plt.ylabel("Total Population")
plt.title("Population by Region")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=df['Taluk'], y=df['Projected_Population_2023_Female'], palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("Region")
plt.ylabel("Total Population")
plt.title("Population by Region")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("Projected_Population_for_2022.csv")

# Data Visualization
plt.figure(figsize=(12,6))
sns.histplot(df['Projected_Population_2023_Total'], bins=30, kde=True)
plt.title("Distribution of Projected Total Population")
plt.xlabel("Population")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df[['Projected_Population_2023_Male', 'Projected_Population_2023_Female']])
plt.title("Boxplot of Male and Female Projected Populations")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df['Taluk'], y=df['Projected_Population_2023_Total'])
plt.xticks(rotation=90)
plt.title("Projected Total Population by Taluk")
plt.xlabel("Taluk")
plt.ylabel("Population")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=df[['Projected_Population_2023_Male', 'Projected_Population_2023_Female']])
plt.title("Violin Plot of Male and Female Populations")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap of Population Data")
plt.show()

# %%
plt.figure(figsize=(12,6))
df_sorted = df.sort_values(by='Projected_Population_2023_Total', ascending=False)
sns.barplot(x=df_sorted['Taluk'].head(10), y=df_sorted['Projected_Population_2023_Total'].head(10))
plt.xticks(rotation=45)
plt.title("Top 10 Taluks by Projected Total Population")
plt.xlabel("Taluk")
plt.ylabel("Population")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.pairplot(df[['Projected_Population_2023_Male', 'Projected_Population_2023_Female', 'Projected_Population_2023_Total']])
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x=df['Taluk'], y=df['Projected_Population_2023_Total'], marker='o', color='b')
plt.xticks(rotation=90)
plt.title("Projected Total Population Trend by Taluk")
plt.xlabel("Taluk")
plt.ylabel("Population")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.stripplot(data=df[['Projected_Population_2023_Male', 'Projected_Population_2023_Female']], jitter=True)
plt.title("Strip Plot of Male and Female Populations")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(df['Projected_Population_2023_Male'], label='Male Population', shade=True)
sns.kdeplot(df['Projected_Population_2023_Female'], label='Female Population', shade=True)
plt.title("Kernel Density Estimation (KDE) of Male and Female Populations")
plt.xlabel("Population")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.pie(df_sorted['Projected_Population_2023_Total'].head(10), labels=df_sorted['Taluk'].head(10), autopct='%1.1f%%', startangle=140)
plt.title("Population Share of Top 10 Taluks")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.regplot(x=df['Projected_Population_2023_Male'], y=df['Projected_Population_2023_Female'])
plt.title("Regression Plot of Male vs Female Population")
plt.xlabel("Male Population")
plt.ylabel("Female Population")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x=df['Projected_Population_2023_Male'], y=df['Projected_Population_2023_Female'])
plt.title("Scatter Plot of Male vs Female Projected Population")
plt.xlabel("Male Population")
plt.ylabel("Female Population")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.swarmplot(data=df[['Projected_Population_2023_Male', 'Projected_Population_2023_Female']])
plt.title("Swarm Plot of Male and Female Populations")
plt.show()
# Out:
# /Users/harshithkothapalli/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 75.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(12,6))
sns.ecdfplot(df['Projected_Population_2023_Total'])
plt.title("Empirical Cumulative Distribution Function (ECDF) of Total Population")
plt.xlabel("Population")
plt.ylabel("Proportion")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.jointplot(x=df['Projected_Population_2023_Male'], y=df['Projected_Population_2023_Female'], kind='hex')
plt.title("Hexbin Joint Plot of Male vs Female Population")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.despine()
sns.heatmap(df.pivot_table(index='Taluk', values='Projected_Population_2023_Total'), annot=True, cmap='YlGnBu')
plt.title("Heatmap of Projected Population by Taluk")
plt.show()

# %%
_, p_value = stats.ttest_rel(df['Projected_Population_2023_Male'], df['Projected_Population_2023_Female'])
print(f"T-test p-value: {p_value}")
# Out:
# T-test p-value: 0.05305893836172422

# %%
from scipy.stats import chi2_contingency

# Create a contingency table for Population and Region
contingency_table = pd.crosstab(df['Taluk'], df['Projected_Population_2023_Total'])

# Perform Chi-Square Test
chi2_stat, p, dof, expected = chi2_contingency(contingency_table)

print(f"Chi-Square Statistic: {chi2_stat:.4f}, P-Value: {p:.4f}")

# Interpretation
if p < 0.05:
    print("There is a significant association between Population and Region.")
else:
    print("There is no significant association between Population and Region.")
# Out:
# Chi-Square Statistic: 55460.0000, P-Value: 0.2394
# There is no significant association between Population and Region.
